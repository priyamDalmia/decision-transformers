# %% [markdown]
# # Decision Transformers

# %%
# imports, env, and helpers 
import numpy as np 
import random 

import torch 
import torch.nn as nn 

from minimal_dt import PointNav1D, collect_random_trajectories

# %%
# main loop (no training, single run across 1 batch of data)
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# training config, and env initialization
config = TrainConfig()
env = PointNav1D(grid_size=10, max_steps=20)

# Collection data 
n_episodes = 10
print(f"Collection {n_episodes} episodes of offline data")
trajectories = collect_random_trajectories(env, n_episodes=n_episodes)
